# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from IPython import display
from IPython.display import clear_output
import time


data = np.load('/hdd_c/data/miniWorld/obs/test.npz')

#data = np.load('/hdd_c/data/miniWorld/dataset_1/eps_1.npz')



obs_list = data['obs']
top_list = data['top']
#ren_list = data['ren']
ent_list = data['ent']

# %%
for i, img in enumerate(obs_list):
    plt.figure(figsize=(8,8))
    plt.imshow(img)
    plt.show()
    print(i)
    time.sleep(0.2)
    clear_output(wait=True)
# Out:
# 39

# %%
for i, img in enumerate(top_list):
    
    plt.figure(figsize=(10,10))
    plt.imshow(img)
    plt.show()
    print(i)
    time.sleep(0.2)
    clear_output(wait=True)
# Out:
# 39

# %%
# for img in ren_list:
#     plt.figure(figsize=(8,8))
#     plt.imshow(img)
#     plt.show()
#     time.sleep(0.3)
#     clear_output(wait=True)

# %%
print(ent_list.shape)
print(ent_list[0])
print(ent_list[2])
# Out:
# (40, 24, 7)
# [[15.39604315  0.          7.5933401  -2.96990311  0.2         2.
#    6.        ]
#  [ 5.53606011  0.         11.41399153  2.59729742  0.2         2.
#    6.        ]
#  [13.86318007  0.         13.85486642 -0.49126773  0.2         2.
#    6.        ]
#  [12.3213279   0.         19.14329883 -0.23466445  0.26917833  0.6
#    0.26917833]
#  [ 4.51854583  0.         14.97424806  0.92835369  0.42906889  0.35
#    0.42906889]
#  [17.12014689  0.         16.76674929 -2.755193    0.38395021  0.6
#    0.38395021]
#  [12.30607239  0.          1.35261518  0.56028717  0.3781021   0.6
#    0.3781021 ]
#  [11.14311984  0.          8.91972472 -1.06601929  0.40206197  0.6
#    0.40206197]
#  [10.39666365  0.         19.12019483 -1.10931191  0.40206197  0.6
#    0.40206197]
#  [ 4.5836624   0.         18.02366665  0.86214603  0.42906889  0.35
#    0.42906889]
#  [18.34096104  0.          5.05559215 -0.80888548  0.26917833  0.6
#    0.26917833]
#  [18.87568532  0.          2.94070472 -1.41332858  0.3781021   0.6
#    0.3781021 ]
#  [ 7.89286489  0.          4.1884091  -0.1740326   0.63768532  0.9
#    0.63768532]
#  [ 6.33276128  0.          4.39493903 -1.29140218  0.38395021  0.6
#    0.38395021]
#  [ 0.5488536   0.         17.9934242   2.55567835  0.3781021   0.6
#    0.3781021 ]
#  [ 5.28967372  0.          1.7717227   0.16647948  0.3781021   0.6
#    0.3781021 ]
#  [ 7.90285298  0.         18.194515   -2.94373752  0.3781021   0.6
#    0.3781021 ]
#  [ 2.10451743  0.          1.68961076 -0.40948353  0.42906889  0.35
#    0.42906889]
#  [ 2.61643057  0.         14.0550571   0.83692562  0.26917833  0.6
#    0.26917833]
